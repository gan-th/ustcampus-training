# %%
dictionary = {1:'abc', 2:'def'}
print(dictionary.get(3))
print(dictionary[1])
# Out:
# None
# abc

# %%
dictionary[3]='xyz'
print(dictionary)
# Out:
# {1: 'abc', 2: 'def', 3: 'xyz'}

# %%
dictionary.pop(1)
# Out:
# 'abc'

# %%
dictionary.popitem()
# both are temporary as it returns the item
# Out:
# (3, 'xyz')

# %%
del dictionary[2]
dictionary.clear()
del dictionary

# %%
dupdict = dictionary.copy()
print(dupdict)
# Out:
# {1: 'abc', 2: 'def'}

# %%
dictio = dict.fromkeys(['math','science','computer'],0)
print(dictio)
# Out:
# {'math': 0, 'science': 0, 'computer': 0}

# %%
lid = {}
print(dir(lid))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
lst = {2:4, 3:9, 4:16, 5:25}
new_dict = {k*2:v*2 for k,v in lst.items() if v>4}
print(new_dict)
# Out:
# {6: 18, 8: 32, 10: 50}
