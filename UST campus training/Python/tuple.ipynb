# %%
lst = (1, (2,3,8),['hi',9.8])
print(lst[-1][0])
# Out:
# hi

# %%
val = (5,)
print(type(val))
# Out:
# <class 'tuple'>

# %%
string = 'prewatech'
string[5]='i'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 string = 'prewatech'
# ----> 2 string[5]='i'
#
# TypeError: 'str' object does not support item assignment

# %%
lst = ('hi',[1,'hello'],3.5,'hello')
lst[1][1]='hai'
print(lst)
# Out:
# ('hi', [1, 'hai'], 3.5, 'hello')

# %%
lst = (('prwatech',)*5)
print(lst)
# Out:
# ('prwatech', 'prwatech', 'prwatech', 'prwatech', 'prwatech')

# %%
# can't delete element from tuple
# use del to delete the whole tuple
del lst

# %%
lst = (1,2,3,4,5,6,3,5,6,3,3,3,9)
print(lst.count(3))
# Out:
# 5

# %%
if 2 in lst:
    print('Hello')
# Out:
# Hello

# %%
print(sorted(lst))
# Out:
# [1, 2, 3, 3, 3, 3, 3, 4, 5, 5, 6, 6, 9]

# %%
print(max(lst))
print(min(lst))
print(sum(lst))
# Out:
# 9
# 1
# 53

# %%
import statistics as sts
sts.mean((1,2,3,4,5))
# Out:
# 3

# %%
import math as mat
mat.factorial(5)
# Out:
# 120
