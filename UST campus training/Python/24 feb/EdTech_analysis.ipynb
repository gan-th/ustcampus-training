# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install kagglehub
# Out:
# ...
#      ---------------------------------------- 0.0/40.1 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.1 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.1 kB 222.6 kB/s eta 0:00:01
#      -------------------------------------- 40.1/40.1 kB 238.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      --------------------- ------------------ 30.7/57.7 kB 1.4 MB/s eta 0:00:01
#      --------------------------------- ---- 51.2/57.7 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 57.7/57.7 kB 608.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/70.6 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/70.6 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 61.4/70.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 70.6/70.6 kB 642.5 kB/s eta 0:00:00
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("akshatsharma0610/edtech-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.36k/4.36k [00:00<00:00, 4.48MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Administrator\.cache\kagglehub\datasets\akshatsharma0610\edtech-dataset\versions\1

# %%
data = pd.read_csv("C:/Users/Administrator/Desktop/UST campus training/edtech.csv")
data.head(10)
# Out:
#    Unnamed: 0                                title     installs     score  \
# 0           0            BYJU'S – The Learning App  100000000.0  4.122065
# 1           1           Duolingo: language lessons  100000000.0  4.573800
# 2           2       IIT JEE, NEET, NCERT Solutions   50000000.0  4.220000
# 3           3                Unacademy Learner App   50000000.0  3.358490
# 4           4  Noon Academy – Student Learning App   10000000.0  4.252337
# 5           5             Cambly - English Teacher   10000000.0  4.171521
# 6           6                               Edmodo   10000000.0  3.953859
# 7           7           Quizlet: Languages & Vocab   10000000.0  4.673288
# 8           8               Udemy - Online Courses   10000000.0  4.353716
# 9           9        Teachmint - The Classroom App   10000000.0  3.967213
#
#       ratings   reviews                size androidVersion  \
# 0   1745108.0     947.0                167M            5.0
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'title', 'installs', 'score', 'ratings', 'reviews',
#        'size', 'androidVersion', 'developer', 'contentRating', 'containsAds',
#        'released', 'updated', 'version'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# Unnamed: 0         0
# title              0
# installs           0
# score              0
# ratings           22
# reviews            0
# size               0
# androidVersion     0
# developer          0
# contentRating      0
# containsAds        0
# released           0
# updated            0
# version            0
# dtype: int64

# %%
new_data = data[['title', 'installs', 'score', 'ratings', 'reviews']]
new_data
# Out:
#                                   title     installs     score     ratings  \
# 0             BYJU'S – The Learning App  100000000.0  4.122065   1745108.0
# 1            Duolingo: language lessons  100000000.0  4.573800  12512116.0
# 2        IIT JEE, NEET, NCERT Solutions   50000000.0  4.220000    574552.0
# 3                 Unacademy Learner App   50000000.0  3.358490    951700.0
# 4   Noon Academy – Student Learning App   10000000.0  4.252337    103191.0
# ..                                  ...          ...       ...         ...
# 76                  Dr course (student)       1000.0  0.000000         NaN
# 77                             Edutechs        500.0  0.000000         NaN
# 78                 Bluelogic EdTech ERP        500.0  0.000000         NaN
# 79                               EdTech        500.0  0.000000         NaN
# 80                   EdTech Middle East          5.0  0.000000         NaN
#
#      reviews
# 0      947.0
# 1   592133.0
# 2      307.0
# ...

# %%
top_ten_apps = data.nlargest(10, 'ratings')
top_ten_apps
# Out:
#     Unnamed: 0                           title     installs     score  \
# 1            1      Duolingo: language lessons  100000000.0  4.573800
# 0            0       BYJU'S – The Learning App  100000000.0  4.122065
# 10          10  Memrise Easy Language Learning   10000000.0  4.580080
# 3            3           Unacademy Learner App   50000000.0  3.358490
# 2            2  IIT JEE, NEET, NCERT Solutions   50000000.0  4.220000
# 11          11        Sololearn: Learn to Code   10000000.0  4.516030
# 7            7      Quizlet: Languages & Vocab   10000000.0  4.673288
# 6            6                          Edmodo   10000000.0  3.953859
# 8            8          Udemy - Online Courses   10000000.0  4.353716
# 9            9   Teachmint - The Classroom App   10000000.0  3.967213
#
#        ratings   reviews                size androidVersion  \
# 1   12512116.0  592133.0  Varies with device         Varies
# 0    1745108.0     947.0                167M            5.0
# ...

# %%
plt.figure(figsize=(15, 6))
plt.bar(top_ten_apps['title'], top_ten_apps['ratings']/10000000, width=0.4)
plt.xticks(rotation=45)
plt.ylabel('App ratings/ 10000000')
plt.title('Top ten apps with the highest ratings')
plt.show()

# %%
#ratings_ads = data.groupby('containsAds')['ratings']

ratings_with_ads = data[data['containsAds']==True][ 'ratings'].dropna().tolist()
ratings_without_ads = data[data['containsAds']==False][ 'ratings'].dropna().tolist()

rating_ads = [ratings_with_ads, ratings_without_ads]
print(rating_ads)
# Out:
# [[12512116.0, 459326.0, 466157.0, 1452079.0, 554749.0, 5631.0, 42862.0, 6937.0, 695.0, 2477.0, 318.0, 191.0, 790.0, 694.0, 71.0, 262.0], [1745108.0, 574552.0, 951700.0, 103191.0, 126401.0, 357547.0, 134739.0, 82461.0, 76453.0, 35681.0, 8323.0, 18492.0, 12023.0, 17874.0, 20206.0, 51403.0, 18982.0, 23345.0, 7084.0, 54691.0, 53044.0, 4571.0, 32033.0, 50941.0, 11192.0, 8374.0, 3395.0, 18618.0, 4692.0, 3007.0, 518.0, 2384.0, 1640.0, 1944.0, 479.0, 258.0, 2047.0, 232.0, 456.0, 425.0, 116.0, 1256.0, 234.0]]

# %%
plt.boxplot(rating_ads)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28b5daa9040>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28b5dac1dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28b5b2ce3c0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x28b5da9c710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x28b5da9f740>,
# ...
#  'means': []}

# %%
plt.pie(avg_ratings, labels=avg_ratings.index)
plt.title('Avg ratings of applications based on wheather they contain ads')
# Out:
# Text(0.5, 1.0, 'Avg ratings of applications based on wheather they contain ads')
