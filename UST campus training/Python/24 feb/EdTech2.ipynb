# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/Administrator/Desktop/UST campus training/online_courses_uses.csv")
data.columns
# Out:
# Index(['Course_ID', 'Course_Name', 'Category', 'Duration (hours)',
#        'Enrolled_Students', 'Completion_Rate (%)', 'Platform', 'Price ($)',
#        'Rating (out of 5)'],
#       dtype='object')

# %%
print(data['Platform'].unique())
# Out:
# ['Coursera' 'edX' 'LinkedIn Learning' 'Udemy']

# %%
avg_compRate_platform = data.groupby(['Platform'])['Completion_Rate (%)'].mean()
print(avg_compRate_platform)
# Out:
# Platform
# Coursera             74.963258
# LinkedIn Learning    75.080557
# Udemy                75.098761
# edX                  75.336501
# Name: Completion_Rate (%), dtype: float64

# %%
plt.plot(avg_compRate_platform, marker='o', color='blue')
plt.xlabel("Platforms")
plt.ylabel("Mean completion rates")
plt.title(" Average completion rate of courses across Platforms")
plt.show()

# %%
# price = data.groupby(['Platform'])['Price ($)']

# plt.boxplot(price)
data.boxplot(column = 'Price ($)', by='Platform')
# Out:
# <Axes: title={'center': 'Price ($)'}, xlabel='Platform'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=data, x='Platform', y='Price ($)')
plt.show()

# %%
udemy_data = data[data['Platform'] == 'Udemy']


plt.scatter(udemy_data['Price ($)'], udemy_data['Completion_Rate (%)'])

# %%
import pandas as pd
import random


columns = [
    "Platform Name", "Courses", "Free/Paid", "Duration",
    "Marketing - Cost per lead", "Marketing - Conversion Rate", "Marketing - Student Enrolled", "Marketing - Marketing ROI",
    "Services - Course Completion Rate", "Services - Engagement Metrics", "Services - Placement Rate", "Services - Course Variety",
    "Branding - Brand Reach", "Branding - Share of Voice", "Branding - Branded Search Trends", "Branding - Referral Rate",
    "Customer Expectation - Customer Satisfaction Score", "Customer Expectation - Customer Effort Score", "Customer Expectation - Net Promoter Score"
]


platforms = ['Platform A', 'Platform B', 'Platform C', 'Platform D', 'Platform E', 'Platform F', 'Platform G', 'Platform H', 'Platform I', 'Platform J']

courses = ['Data Science', 'Web Development', 'AI & ML', 'Cloud Computing', 'Digital Marketing', 'Cyber Security', 'Blockchain', 'UX/UI Design']


def generate_random_data():
    return {
        "Platform Name": random.choice(platforms),
        "Courses": random.choice(courses),
        "Free/Paid": random.choice(['Free', 'Paid']),
        "Duration": random.choice(['4 weeks', '6 weeks', '8 weeks', '10 weeks', '12 weeks']),
        "Marketing - Cost per lead": round(random.uniform(30, 150), 2),
        "Marketing - Conversion Rate": round(random.uniform(2, 10), 2),
        "Marketing - Student Enrolled": random.randint(50, 300),
        "Marketing - Marketing ROI": round(random.uniform(2.0, 5.0), 2),
        "Services - Course Completion Rate": random.randint(60, 95),
        "Services - Engagement Metrics": random.choice(['Low', 'Medium', 'High']),
        "Services - Placement Rate": random.randint(60, 100),
        "Services - Course Variety": random.randint(3, 8),
        "Branding - Brand Reach": random.randint(50000, 250000),
        "Branding - Share of Voice": random.randint(5, 20),
        "Branding - Branded Search Trends": random.randint(30, 75),
        "Branding - Referral Rate": random.randint(10, 25),
        "Customer Expectation - Customer Satisfaction Score": round(random.uniform(4.0, 5.0), 1),
        "Customer Expectation - Customer Effort Score": random.randint(1, 5),
        "Customer Expectation - Net Promoter Score": random.randint(40, 80)
    }


data = [generate_random_data() for _ in range(50)]
df = pd.DataFrame(data, columns=columns)

file_path = 'C:/Users/Administrator/Desktop/UST campus training/platform_data.csv'
df.to_csv(file_path, index=False)

print(f"Dataset saved to {file_path}")
# Out:
# Dataset saved to C:/Users/Administrator/Desktop/UST campus training/platform_data.csv

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Administrator/Desktop/UST campus training/platform_data.csv')
df
# Out:
#    Platform Name            Courses Free/Paid  Duration  \
# 0     Platform J    Cloud Computing      Paid  10 weeks
# 1     Platform G            AI & ML      Free   4 weeks
# 2     Platform B       Data Science      Paid  12 weeks
# 3     Platform J     Cyber Security      Free  10 weeks
# 4     Platform E    Web Development      Free  10 weeks
# 5     Platform F    Web Development      Free  12 weeks
# 6     Platform G    Cloud Computing      Free   8 weeks
# 7     Platform A         Blockchain      Paid  12 weeks
# 8     Platform F  Digital Marketing      Free   8 weeks
# 9     Platform H    Web Development      Free   6 weeks
# 10    Platform I     Cyber Security      Free  10 weeks
# 11    Platform E       UX/UI Design      Paid   4 weeks
# 12    Platform E            AI & ML      Paid   8 weeks
# 13    Platform A     Cyber Security      Free  12 weeks
# 14    Platform B  Digital Marketing      Paid   8 weeks
# 15    Platform C    Cloud Computing      Paid   6 weeks
# ...

# %%
df.columns
# Out:
# Index(['Platform Name', 'Courses', 'Free/Paid', 'Duration',
#        'Marketing - Cost per lead', 'Marketing - Conversion Rate',
#        'Marketing - Student Enrolled', 'Marketing - Marketing ROI',
#        'Services - Course Completion Rate', 'Services - Engagement Metrics',
#        'Services - Placement Rate', 'Services - Course Variety',
#        'Branding - Brand Reach', 'Branding - Share of Voice',
#        'Branding - Branded Search Trends', 'Branding - Referral Rate',
#        'Customer Expectation - Customer Satisfaction Score',
#        'Customer Expectation - Customer Effort Score',
#        'Customer Expectation - Net Promoter Score'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
descriptive_stats = df[['Customer Expectation - Customer Satisfaction Score', 
                        'Customer Expectation - Customer Effort Score', 
                        'Customer Expectation - Net Promoter Score']].describe()
print("Descriptive Statistics:\n", descriptive_stats)
# Out:
# Descriptive Statistics:
#         Customer Expectation - Customer Satisfaction Score  \
# count                                          50.000000
# mean                                            4.398000
# std                                             0.311343
# min                                             4.000000
# 25%                                             4.100000
# 50%                                             4.300000
# 75%                                             4.700000
# max                                             5.000000
#
#        Customer Expectation - Customer Effort Score  \
# count                                     50.000000
# mean                                       2.780000
# std                                        1.460919
# min                                        1.000000
# 25%                                        1.250000
# 50%                                        3.000000
# 75%                                        4.000000
# ...

# %%
# Correlation analysis between the three customer expectation columns
correlation_matrix = df[['Customer Expectation - Customer Satisfaction Score',
                         'Customer Expectation - Customer Effort Score',
                         'Customer Expectation - Net Promoter Score']].corr()

# Print the correlation matrix
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Correlation Matrix:
#                                                      Customer Expectation - Customer Satisfaction Score  \
# Customer Expectation - Customer Satisfaction Score                                           1.000000
# Customer Expectation - Customer Effort Score                                                -0.032395
# Customer Expectation - Net Promoter Score                                                    0.120507
#
#                                                     Customer Expectation - Customer Effort Score  \
# Customer Expectation - Customer Satisfaction Score                                     -0.032395
# Customer Expectation - Customer Effort Score                                            1.000000
# Customer Expectation - Net Promoter Score                                               0.160223
#
#                                                     Customer Expectation - Net Promoter Score
# ...

# %%
plt.figure(figsize=(15, 5))

# Customer Satisfaction Score
plt.subplot(1, 3, 1)
sns.histplot(df['Customer Expectation - Customer Satisfaction Score'], kde=True, color='skyblue')
plt.title('Customer Satisfaction Score Distribution')


# Customer Effort Score
plt.subplot(1, 3, 2)
sns.histplot(df['Customer Expectation - Customer Effort Score'], kde=True, color='lightgreen')
plt.title('Customer Effort Score Distribution')

# Net Promoter Score
plt.subplot(1, 3, 3)
sns.histplot(df['Customer Expectation - Net Promoter Score'], kde=True, color='lightcoral')
plt.title('Net Promoter Score Distribution')

plt.tight_layout()
plt.show()

# %%
# Boxplots to identify outliers and distribution characteristics
plt.figure(figsize=(15, 5))

# Customer Satisfaction Score Boxplot
plt.subplot(1, 3, 1)
sns.boxplot(x=df['Customer Expectation - Customer Satisfaction Score'], color='skyblue')
plt.title('Customer Satisfaction Score Boxplot')

# Customer Effort Score Boxplot
plt.subplot(1, 3, 2)
sns.boxplot(x=df['Customer Expectation - Customer Effort Score'], color='lightgreen')
plt.title('Customer Effort Score Boxplot')

# Net Promoter Score Boxplot
plt.subplot(1, 3, 3)
sns.boxplot(x=df['Customer Expectation - Net Promoter Score'], color='lightcoral')
plt.title('Net Promoter Score Boxplot')

plt.tight_layout()
plt.show()

# %%
# Scatterplots to visualize relationships between scores
plt.figure(figsize=(12, 6))

# Satisfaction vs Effort Score
plt.subplot(1, 2, 1)
sns.scatterplot(x=df['Customer Expectation - Customer Satisfaction Score'],
                y=df['Customer Expectation - Customer Effort Score'],
                color='skyblue')
plt.title('Customer Satisfaction vs Effort Score')
plt.xlabel('Satisfaction Score')
plt.ylabel('Effort Score')

# Satisfaction vs NPS
plt.subplot(1, 2, 2)
sns.scatterplot(x=df['Customer Expectation - Customer Satisfaction Score'],
                y=df['Customer Expectation - Net Promoter Score'],
                color='lightcoral')
plt.title('Customer Satisfaction vs NPS')
plt.xlabel('Satisfaction Score')
plt.ylabel('Net Promoter Score')

plt.tight_layout()
plt.show()

# %%
# Additional Analysis: Check if there are any patterns with 'Free/Paid' courses
grouped_by_paid_status = df.groupby('Free/Paid').agg({
    'Customer Expectation - Customer Satisfaction Score': 'mean',
    'Customer Expectation - Customer Effort Score': 'mean',
    'Customer Expectation - Net Promoter Score': 'mean'
})

print("\nAverage Customer Expectation by Free/Paid:\n", grouped_by_paid_status)

# Correlation between customer satisfaction and NPS to see if there is a positive relationship
sns.lmplot(x='Customer Expectation - Customer Satisfaction Score',
           y='Customer Expectation - Net Promoter Score',
           data=df, aspect=1.5, height=6)
plt.title('Relationship Between Satisfaction and Net Promoter Score')
plt.xlabel('Customer Satisfaction Score')
plt.ylabel('Net Promoter Score')
plt.show()
# Out:
# Average Customer Expectation by Free/Paid:
#             Customer Expectation - Customer Satisfaction Score  \
# Free/Paid
# Free                                                4.324138
# Paid                                                4.500000
#
#            Customer Expectation - Customer Effort Score  \
# Free/Paid
# Free                                           2.862069
# Paid                                           2.666667
#
#            Customer Expectation - Net Promoter Score
# Free/Paid
# Free                                       60.965517
# Paid                                       61.857143

# %%
# Boxplot to compare Customer Satisfaction based on Free/Paid
plt.figure(figsize=(12, 6))
sns.boxplot(x='Free/Paid', y='Customer Expectation - Customer Satisfaction Score', data=df, palette="Set2")
plt.title('Customer Satisfaction Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Customer Satisfaction Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\2227869117.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Free/Paid', y='Customer Expectation - Customer Satisfaction Score', data=df, palette="Set2")

# %%
# Boxplot to compare Customer Effort Score based on Free/Paid
plt.figure(figsize=(12, 6))
sns.boxplot(x='Free/Paid', y='Customer Expectation - Customer Effort Score', data=df, palette="Set2")
plt.title('Customer Effort Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Customer Effort Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\1853286421.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Free/Paid', y='Customer Expectation - Customer Effort Score', data=df, palette="Set2")

# %%
# Boxplot to compare Net Promoter Score based on Free/Paid
plt.figure(figsize=(12, 6))
sns.boxplot(x='Free/Paid', y='Customer Expectation - Net Promoter Score', data=df, palette="Set2")
plt.title('Net Promoter Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Net Promoter Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\2536340719.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Free/Paid', y='Customer Expectation - Net Promoter Score', data=df, palette="Set2")

# %%
# Bar chart to show the average customer expectations for Free vs Paid courses
avg_expectations = df.groupby('Free/Paid').agg({
    'Customer Expectation - Customer Satisfaction Score': 'mean',
    'Customer Expectation - Customer Effort Score': 'mean',
    'Customer Expectation - Net Promoter Score': 'mean'
}).reset_index()

# Plotting the bar chart
avg_expectations.plot(x='Free/Paid', kind='bar', figsize=(12, 6), color=['skyblue', 'lightcoral','red'])
plt.title('Average Customer Expectations by Free/Paid')
plt.ylabel('Average Score')
plt.xlabel('Free/Paid')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Violin plot to visualize the distribution of satisfaction score by Free/Paid
plt.figure(figsize=(12, 6))
sns.violinplot(x='Free/Paid', y='Customer Expectation - Customer Satisfaction Score', data=df, palette="Set2")
plt.title('Distribution of Customer Satisfaction Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Customer Satisfaction Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\1483627340.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Free/Paid', y='Customer Expectation - Customer Satisfaction Score', data=df, palette="Set2")

# %%
# Violin plot to visualize the distribution of Effort Score by Free/Paid
plt.figure(figsize=(12, 6))
sns.violinplot(x='Free/Paid', y='Customer Expectation - Customer Effort Score', data=df, palette="Set2")
plt.title('Distribution of Customer Effort Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Customer Effort Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\3865060494.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Free/Paid', y='Customer Expectation - Customer Effort Score', data=df, palette="Set2")

# %%
# Violin plot to visualize the distribution of Net Promoter Score by Free/Paid
plt.figure(figsize=(12, 6))
sns.violinplot(x='Free/Paid', y='Customer Expectation - Net Promoter Score', data=df, palette="Set2")
plt.title('Distribution of Net Promoter Score by Free/Paid')
plt.xlabel('Free/Paid')
plt.ylabel('Net Promoter Score')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7424\1644967389.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Free/Paid', y='Customer Expectation - Net Promoter Score', data=df, palette="Set2")
