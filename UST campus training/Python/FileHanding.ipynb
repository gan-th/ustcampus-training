# %%
import os
lst = open("C:/Users/Administrator/Desktop/file.txt")

lst.close()

# %%
import os
#os.env("C:/Users/Administrator/Desktop")
lst = open("C:/Users/Administrator/Desktop/file.txt","w")
lst.write("this is the first module \n")
lst.write("this is the 2nd module")
lst.close()

# %%
lst = open("file.txt","r")
lst.read()
# Out:
# 'this is the first module \nthis is the 2nd module'

# %%
lst = open("file.txt","r")
lst.read(20)
# Out:
# 'this is the first mo'

# %%
lst.read(20)
# Out:
# 'dule \nthis is the 2n'

# %%
lst.seek(0)
lst.read(20)
# Out:
# 'this is the first mo'

# %%
string = "This is a string"
print(string[:4])
# Out:
# This

# %%
lst.seek(0)
for line in lst:
    print(line)
# Out:
# this is the first module
#
# this is the 2nd module

# %%
lst = open("C:/Users/Administrator/Desktop/file.txt","r")
lst.readline()
lst.close()

# %%
import os
os.rename('C:/Users/Administrator/Desktop/file.txt','C:/Users/Administrator/Desktop/smaple.txt')

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("C:/Users/Administrator/Desktop")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
#os.listdir(os.getcwd())
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'desktop.ini',
#  'file.txt',
#  'Microsoft Edge.lnk',
#  'MongoDB Compass.lnk',
#  'Readme - Shortcut.lnk',
#  'smaple.txt',
#  'UST campus training']

# %%
os.mkdir("Training")
