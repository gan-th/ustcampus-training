# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.chdir("C:/Users/Administrator/Desktop")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
os.mkdir('Trial')
os.chdir("C:/Users/Administrator/Desktop/Trial")
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop\\Trial'

# %%
lst = open('file.txt','w')
lst.write('Hello how are you')
lst.close()

# %%
lst = open('file.txt','r')
lst.read()
# Out:
# 'Hello how are you'

# %%
lst.close()

# %%
os.remove('file.txt')

# %%
os.chdir("C:/Users/Administrator/Desktop")
os.rmdir("Trial")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Desktop'

# %%
import shutil

shutil.rmtree("C:/Users/Administrator/Desktop/Trial")
